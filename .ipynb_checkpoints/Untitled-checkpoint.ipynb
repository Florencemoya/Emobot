# %%
# !pip install geopandas
# Out:
# Collecting geopandas
#   Obtaining dependency information for geopandas from https://files.pythonhosted.org/packages/27/27/2687abaa2ac02b5814e2929a5033da1e5d132c19a904dc56f77f63fd6eb9/geopandas-0.14.0-py3-none-any.whl.metadata
#   Downloading geopandas-0.14.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting fiona>=1.8.21 (from geopandas)
#   Obtaining dependency information for fiona>=1.8.21 from https://files.pythonhosted.org/packages/b0/7f/2de46a2630f609b7520d74ffc7692d4969b1fa1dd3c82f62c7967183d365/Fiona-1.9.4.post1-cp311-cp311-win_amd64.whl.metadata
#   Downloading Fiona-1.9.4.post1-cp311-cp311-win_amd64.whl.metadata (50 kB)
#      ---------------------------------------- 0.0/50.6 kB ? eta -:--:--
#      ---------------------------------------- 50.6/50.6 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\moya\anaconda3\lib\site-packages (from geopandas) (23.0)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\moya\anaconda3\lib\site-packages (from geopandas) (1.5.3)
# Collecting pyproj>=3.3.0 (from geopandas)
#   Obtaining dependency information for pyproj>=3.3.0 from https://files.pythonhosted.org/packages/c8/5a/215a1894e50167d91b471d8fc413ca30034c48e5d3dfac78d12df4c840d5/pyproj-3.6.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading pyproj-3.6.0-cp311-cp311-win_amd64.whl.metadata (30 kB)
# Collecting shapely>=1.8.0 (from geopandas)
#   Downloading shapely-2.0.1-cp311-cp311-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#      --------- ------------------------------ 0.3/1.4 MB 10.6 MB/s eta 0:00:01
#      -------------------- ------------------- 0.7/1.4 MB 8.9 MB/s eta 0:00:01
#      -------------------------------- ------- 1.1/1.4 MB 10.1 MB/s eta 0:00:01
#      ---------------------------------------- 1.4/1.4 MB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.2.0 in c:\users\moya\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (22.1.0)
# Requirement already satisfied: certifi in c:\users\moya\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (2023.7.22)
# Requirement already satisfied: click~=8.0 in c:\users\moya\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Collecting click-plugins>=1.0 (from fiona>=1.8.21->geopandas)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5 (from fiona>=1.8.21->geopandas)
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: six in c:\users\moya\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\moya\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\moya\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\moya\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (1.24.3)
# Requirement already satisfied: colorama in c:\users\moya\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)
# Downloading geopandas-0.14.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------------- ------------------------ 0.4/1.1 MB 13.2 MB/s eta 0:00:01
#    -------------------------------- ------- 0.9/1.1 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 9.9 MB/s eta 0:00:00
# Downloading Fiona-1.9.4.post1-cp311-cp311-win_amd64.whl (22.7 MB)
#    ---------------------------------------- 0.0/22.7 MB ? eta -:--:--
#     --------------------------------------- 0.5/22.7 MB 9.4 MB/s eta 0:00:03
#    - -------------------------------------- 0.9/22.7 MB 11.6 MB/s eta 0:00:02
#    -- ------------------------------------- 1.2/22.7 MB 11.3 MB/s eta 0:00:02
#    -- ------------------------------------- 1.7/22.7 MB 10.8 MB/s eta 0:00:02
#    --- ------------------------------------ 2.1/22.7 MB 10.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 2.5/22.7 MB 10.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 3.0/22.7 MB 11.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 3.4/22.7 MB 11.3 MB/s eta 0:00:02
#    ------ --------------------------------- 3.9/22.7 MB 11.2 MB/s eta 0:00:02
#    ------- -------------------------------- 4.4/22.7 MB 11.1 MB/s eta 0:00:02
#    -------- ------------------------------- 4.8/22.7 MB 11.0 MB/s eta 0:00:02
#    --------- ------------------------------ 5.3/22.7 MB 11.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 5.7/22.7 MB 11.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 6.2/22.7 MB 11.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 6.6/22.7 MB 11.5 MB/s eta 0:00:02
#    ------------ --------------------------- 7.1/22.7 MB 11.3 MB/s eta 0:00:02
#    ------------- -------------------------- 7.5/22.7 MB 11.5 MB/s eta 0:00:02
#    -------------- ------------------------- 8.0/22.7 MB 11.3 MB/s eta 0:00:02
#    -------------- ------------------------- 8.4/22.7 MB 11.4 MB/s eta 0:00:02
#    --------------- ------------------------ 8.9/22.7 MB 11.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 9.3/22.7 MB 11.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 9.8/22.7 MB 11.4 MB/s eta 0:00:02
#    ------------------ --------------------- 10.3/22.7 MB 11.5 MB/s eta 0:00:02
#    ------------------ --------------------- 10.7/22.7 MB 11.5 MB/s eta 0:00:02
#    ------------------- -------------------- 11.2/22.7 MB 11.5 MB/s eta 0:00:01
#    -------------------- ------------------- 11.7/22.7 MB 11.5 MB/s eta 0:00:01
#    --------------------- ------------------ 12.1/22.7 MB 11.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 12.6/22.7 MB 11.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 13.0/22.7 MB 11.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 13.5/22.7 MB 11.7 MB/s eta 0:00:01
#    ------------------------ --------------- 14.0/22.7 MB 11.9 MB/s eta 0:00:01
#    ------------------------- -------------- 14.4/22.7 MB 11.7 MB/s eta 0:00:01
#    -------------------------- ------------- 14.9/22.7 MB 11.7 MB/s eta 0:00:01
#    --------------------------- ------------ 15.3/22.7 MB 11.7 MB/s eta 0:00:01
#    --------------------------- ------------ 15.9/22.7 MB 11.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 16.3/22.7 MB 11.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 16.8/22.7 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 17.2/22.7 MB 11.7 MB/s eta 0:00:01
#    ------------------------------- -------- 17.7/22.7 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 18.2/22.7 MB 11.7 MB/s eta 0:00:01
#    -------------------------------- ------- 18.6/22.7 MB 11.9 MB/s eta 0:00:01
#    --------------------------------- ------ 19.1/22.7 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 19.4/22.7 MB 11.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 19.9/22.7 MB 11.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 20.3/22.7 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------ --- 20.8/22.7 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- -- 21.2/22.7 MB 11.7 MB/s eta 0:00:01
#    -------------------------------------- - 21.7/22.7 MB 11.7 MB/s eta 0:00:01
#    -------------------------------------- - 22.0/22.7 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  22.3/22.7 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  22.7/22.7 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  22.7/22.7 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 22.7/22.7 MB 10.2 MB/s eta 0:00:00
# Downloading pyproj-3.6.0-cp311-cp311-win_amd64.whl (5.7 MB)
#    ---------------------------------------- 0.0/5.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.7 MB 15.2 MB/s eta 0:00:01
#    ------ --------------------------------- 1.0/5.7 MB 15.2 MB/s eta 0:00:01
#    -------- ------------------------------- 1.2/5.7 MB 13.1 MB/s eta 0:00:01
#    --------- ------------------------------ 1.4/5.7 MB 9.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.5/5.7 MB 8.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.6/5.7 MB 7.2 MB/s eta 0:00:01
#    ------------ --------------------------- 1.8/5.7 MB 6.6 MB/s eta 0:00:01
#    -------------- ------------------------- 2.1/5.7 MB 7.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.4/5.7 MB 7.0 MB/s eta 0:00:01
#    ------------------- -------------------- 2.8/5.7 MB 7.3 MB/s eta 0:00:01
#    --------------------- ------------------ 3.1/5.7 MB 7.6 MB/s eta 0:00:01
#    ------------------------ --------------- 3.5/5.7 MB 7.6 MB/s eta 0:00:01
#    -------------------------- ------------- 3.8/5.7 MB 7.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.2/5.7 MB 7.9 MB/s eta 0:00:01
#    ------------------------------- -------- 4.5/5.7 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.9/5.7 MB 8.0 MB/s eta 0:00:01
#    ------------------------------------ --- 5.3/5.7 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  5.7/5.7 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 5.7/5.7 MB 7.8 MB/s eta 0:00:00
# Installing collected packages: shapely, pyproj, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.4.post1 geopandas-0.14.0 pyproj-3.6.0 shapely-2.0.1

# %%
#importing libraries
import geopandas as gpd
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
change_type_map = {'Demolition': 0, 'Road': 1, 'Residential': 2, 'Commercial': 3, 'Industrial': 4,
       'Mega Projects': 5}

# %%
## Read csvs

train_df = gpd.read_file('train.geojson', index_col=0)
test_df = gpd.read_file('test.geojson', index_col=0)

# %% [markdown]
# # Feature Engineering

# %%
# Create a copy of the test DataFrame to preserve the original data
test_df1 = test_df.copy()

# %%
# Create a copy of the train DataFrame to preserve the original data
train_df1 = train_df.copy()

# %%
# Count the number of occurrences for each unique value in the 'change_status_date1' column
train_df1['change_status_date1'].value_counts()
# Out:
# Land Cleared            98071
# Prior Construction      91489
# Greenland               84616
# Construction Midway     15972
# Construction Started     8147
# Materials Dumped         8029
# NA                       1577
# Operational               890
# Excavation                626
# Construction Done         589
# Name: change_status_date1, dtype: int64

# %%
# Count the number of occurrences for each unique value in the 'change_status_date2' column
train_df1['change_status_date2'].value_counts()
# Out:
# Land Cleared            86354
# Prior Construction      76955
# Greenland               69045
# Construction Midway     31810
# Construction Done       25716
# Materials Dumped         9221
# Construction Started     7346
# NA                       1512
# Operational              1167
# Excavation                880
# Name: change_status_date2, dtype: int64

# %%
# Count the number of occurrences for each unique value in the 'change_status_date3' column
train_df1['change_status_date3'].value_counts()
# Out:
# Land Cleared            71884
# Construction Done       64616
# Prior Construction      62987
# Greenland               48238
# Construction Midway     40710
# Materials Dumped         9576
# Construction Started     7203
# NA                       2029
# Operational              1760
# Excavation               1003
# Name: change_status_date3, dtype: int64

# %%
# Count the number of occurrences for each unique value in the 'change_status_date4' column
train_df1['change_status_date4'].value_counts()
# Out:
# Construction Done       112985
# Land Cleared             58198
# Prior Construction       47759
# Construction Midway      41638
# Greenland                27943
# Materials Dumped         10203
# Construction Started      5933
# Operational               2635
# NA                        1577
# Excavation                1135
# Name: change_status_date4, dtype: int64

# %%
# Count the number of occurrences for each unique value in the 'change_status_date5' column
train_df1['change_status_date5'].value_counts()
# Out:
# Construction Done       178240
# Land Cleared             38172
# Prior Construction       35432
# Construction Midway      23718
# Greenland                14819
# Materials Dumped         10136
# Operational               3720
# Construction Started      3224
# NA                        1512
# Excavation                1033
# Name: change_status_date5, dtype: int64

# %% [markdown]
# ## train_df

# %%
# Filter out rows in train_df1 where 'change_status_date5' is not equal to 'NA'
train_df1 = train_df1[train_df1['change_status_date5'] != 'NA']

# %%
# Filter out rows in train_df1 where 'change_status_date1' is not equal to 'NA'
train_df1 = train_df1[train_df1['change_status_date1'] != 'NA']

# %%
# Filter out rows in train_df1 where 'change_status_date2' is not equal to 'NA'
train_df1 = train_df1[train_df1['change_status_date2'] != 'NA']

# %%
# Filter out rows in train_df1 where 'change_status_date4' is not equal to 'NA'
train_df1 = train_df1[train_df1['change_status_date4'] != 'NA']

# %%
# Filter out rows in train_df1 where 'geography_types' is not equal to 'None'
train_df1 = train_df1[train_df1['geography_types'] != 'None']

# %%
# Filter out rows in train_df1 where 'urban_types' is not equal to 'None'
train_df1 = train_df1[train_df1['urban_types'] != 'None']

# %% [markdown]
# ### For the encoding of geography_types and urban_types, I did not use the one-hot encoder because the number of categories in the test_df and train_df variables for different geography_types was not the same. We have 180 categories in train_df and 159 in test_df. I opted for the LabelEncoder in order to maintain the same number of variables in both test_df and train_df

# %%
# Encoding the categorical column 'geography_types''
le = LabelEncoder()
train_df1['geography_types'] = le.fit_transform(train_df1.geography_types)

# %%
# Encoding the categorical column 'urban_types'
le = LabelEncoder()
train_df1['urban_types'] = le.fit_transform(train_df1.geography_types)

# %%
from shapely.geometry import shape

# Calculate the area for each polygon in train_df1

for index, row in train_df1.iterrows():
    geometry = row['geometry']
    superficie = shape(geometry).area
    train_df1.at[index, 'superficie'] = superficie

# Display the DataFrame with the new 'area' column
train_df1
# Out:
#          index  change_type change_status_date1  change_status_date2  \
# 0            0   Commercial        Land Cleared  Construction Midway
# 1            1   Commercial           Greenland            Greenland
# 2            2   Commercial        Land Cleared         Land Cleared
# 3            3   Commercial        Land Cleared         Land Cleared
# 4            4   Commercial        Land Cleared         Land Cleared
# ...        ...          ...                 ...                  ...
# 309999  309999   Commercial           Greenland            Greenland
# 310001  310001  Residential  Prior Construction   Prior Construction
# 310002  310002  Residential        Land Cleared         Land Cleared
# 310003  310003   Commercial    Materials Dumped         Land Cleared
# 310004  310004   Commercial        Land Cleared         Land Cleared
#
#          change_status_date3  change_status_date4 change_status_date5  \
# 0          Construction Done    Construction Done   Construction Done
# 1          Construction Done    Construction Done   Construction Done
# 2          Construction Done    Construction Done   Construction Done
# 3        Construction Midway  Construction Midway   Construction Done
# 4       Construction Started  Construction Midway   Construction Done
# ...                      ...                  ...                 ...
# 309999             Greenland            Greenland   Construction Done
# 310001    Prior Construction         Land Cleared   Construction Done
# 310002          Land Cleared         Land Cleared   Construction Done
# 310003          Land Cleared         Land Cleared   Construction Done
# 310004          Land Cleared            Greenland           Greenland
#
#              date1       date2       date3       date4       date5  \
# 0       29-05-2014  13-09-2015  25-02-2017  10-10-2018  19-05-2020
# 1       29-05-2014  13-09-2015  25-02-2017  10-10-2018  19-05-2020
# 2       29-05-2014  13-09-2015  25-02-2017  10-10-2018  19-05-2020
# 3       29-05-2014  13-09-2015  25-02-2017  10-10-2018  19-05-2020
# 4       29-05-2014  13-09-2015  25-02-2017  10-10-2018  19-05-2020
# ...            ...         ...         ...         ...         ...
# 309999  18-11-2014  01-03-2016  01-01-2018  01-05-2019  01-04-2020
# 310001  18-11-2014  01-03-2016  01-01-2018  01-05-2019  01-04-2020
# 310002  18-11-2014  01-03-2016  01-01-2018  01-05-2019  01-04-2020
# 310003  18-11-2014  01-03-2016  01-01-2018  01-05-2019  01-04-2020
# 310004  18-11-2014  01-03-2016  01-01-2018  01-05-2019  01-04-2020
#
#         urban_types  geography_types  \
# 0               135              135
# 1               156              156
# 2               156              156
# 3               135              135
# 4               135              135
# ...             ...              ...
# 309999          119              119
# 310001           42               42
# 310002          142              142
# 310003          142              142
# 310004          135              135
#
#                                                  geometry    superficie
# 0       POLYGON ((116.97563 38.89002, 116.97590 38.890...  1.237159e-06
# 1       POLYGON ((116.97500 38.88969, 116.97524 38.889...  4.701495e-07
# 2       POLYGON ((116.97519 38.88847, 116.97568 38.888...  4.536881e-07
# 3       POLYGON ((116.97630 38.89017, 116.97730 38.890...  2.936349e-07
# 4       POLYGON ((116.97751 38.89037, 116.97854 38.890...  2.905206e-07
# ...                                                   ...           ...
# 309999  POLYGON ((139.81493 35.60963, 139.81484 35.609...  3.080072e-08
# 310001  POLYGON ((139.80642 35.60416, 139.80597 35.603...  1.428818e-07
# 310002  POLYGON ((139.80857 35.60407, 139.80831 35.603...  6.767191e-08
# 310003  POLYGON ((139.80927 35.60445, 139.80889 35.604...  8.923550e-08
# 310004  POLYGON ((139.80688 35.60937, 139.80645 35.609...  9.931494e-08
#
# [263208 rows x 16 columns]

# %%
# Encoding the categorical column 'change_status_date4'
le = LabelEncoder()
train_df1['change_status_date4'] = le.fit_transform(train_df1.change_status_date4)

# %%
# Encoding the categorical column 'change_status_date1'
le = LabelEncoder()
train_df1['change_status_date1'] = le.fit_transform(train_df1.change_status_date1)

# %%
# Encoding the categorical column 'change_status_date2'
le = LabelEncoder()
train_df1['change_status_date2'] = le.fit_transform(train_df1.change_status_date2)

# %%
# Encoding the categorical column 'change_status_date3'
le = LabelEncoder()
train_df1['change_status_date3'] = le.fit_transform(train_df1.change_status_date3)

# %%
# Encoding the categorical column 'change_status_date5'
le = LabelEncoder()
train_df1['change_status_date5'] = le.fit_transform(train_df1.change_status_date5)

# %%
from datetime import datetime
# Convert strings to datetime objects
train_df1['date1'] = train_df1['date1'].apply(lambda x: datetime.strptime(x, '%d-%m-%Y'))
train_df1['date2'] = train_df1['date2'].apply(lambda x: datetime.strptime(x, '%d-%m-%Y'))
train_df1['date3'] = train_df1['date3'].apply(lambda x: datetime.strptime(x, '%d-%m-%Y'))
train_df1['date4'] = train_df1['date4'].apply(lambda x: datetime.strptime(x, '%d-%m-%Y'))
train_df1['date5'] = train_df1['date5'].apply(lambda x: datetime.strptime(x, '%d-%m-%Y'))

# Calculate the number of days between consecutive dates
train_df1['jours_entre_1_et_2'] = (train_df1['date2'] - train_df1['date1']).dt.days
train_df1['jours_entre_2_et_3'] = (train_df1['date3'] - train_df1['date2']).dt.days
train_df1['jours_entre_3_et_4'] = (train_df1['date4'] - train_df1['date3']).dt.days
train_df1['jours_entre_4_et_5'] = (train_df1['date5'] - train_df1['date4']).dt.days

# %%
# Remove the columns 'date1', 'date2', 'date3', 'date4', 'date5' from train_df1
train_df1 = train_df1.drop(columns=['date1'], axis=1)
train_df1 = train_df1.drop(columns=['date2'], axis=1)
train_df1 = train_df1.drop(columns=['date3'], axis=1)
train_df1 = train_df1.drop(columns=['date4'], axis=1)
train_df1 = train_df1.drop(columns=['date5'], axis=1)

# %%
# Remove the columns'geometry'from train_df1
train_df1 = train_df1.drop(columns=['geometry'], axis=1)

# %%
train_df1
# Out:
#          index  change_type  change_status_date1  change_status_date2  \
# 0            0   Commercial                    5                    1
# 1            1   Commercial                    4                    4
# 2            2   Commercial                    5                    5
# 3            3   Commercial                    5                    5
# 4            4   Commercial                    5                    5
# ...        ...          ...                  ...                  ...
# 309999  309999   Commercial                    4                    4
# 310001  310001  Residential                    8                    8
# 310002  310002  Residential                    5                    5
# 310003  310003   Commercial                    6                    5
# 310004  310004   Commercial                    5                    5
#
#         change_status_date3  change_status_date4  change_status_date5  \
# 0                         0                    0                    0
# 1                         0                    0                    0
# 2                         0                    0                    0
# 3                         1                    1                    0
# 4                         2                    1                    0
# ...                     ...                  ...                  ...
# 309999                    4                    4                    0
# 310001                    8                    5                    0
# 310002                    5                    5                    0
# 310003                    5                    5                    0
# 310004                    5                    4                    4
#
#         urban_types  geography_types    superficie  jours_entre_1_et_2  \
# 0               135              135  1.237159e-06                 472
# 1               156              156  4.701495e-07                 472
# 2               156              156  4.536881e-07                 472
# 3               135              135  2.936349e-07                 472
# 4               135              135  2.905206e-07                 472
# ...             ...              ...           ...                 ...
# 309999          119              119  3.080072e-08                 469
# 310001           42               42  1.428818e-07                 469
# 310002          142              142  6.767191e-08                 469
# 310003          142              142  8.923550e-08                 469
# 310004          135              135  9.931494e-08                 469
#
#         jours_entre_2_et_3  jours_entre_3_et_4  jours_entre_4_et_5
# 0                      531                 592                 587
# 1                      531                 592                 587
# 2                      531                 592                 587
# 3                      531                 592                 587
# 4                      531                 592                 587
# ...                    ...                 ...                 ...
# 309999                 671                 485                 336
# 310001                 671                 485                 336
# 310002                 671                 485                 336
# 310003                 671                 485                 336
# 310004                 671                 485                 336
#
# [263208 rows x 14 columns]

# %% [markdown]
# # test_df

# %%
# Filter out rows in test_df1 where 'change_status_date1' is not equal to 'NA'
test_df1 = test_df1[test_df1['change_status_date1'] != 'NA']

# %%
# Filter out rows in test_df1 where 'change_status_date2' is not equal to 'NA'
test_df1 = test_df1[test_df1['change_status_date2'] != 'NA']

# %%
# Filter out rows in train_df1 where 'change_status_date3' is not equal to 'NA'
train_df1 = train_df1[train_df1['change_status_date3'] != 'NA']

# %%
# Filter out rows in test_df1 where 'change_status_date4' is not equal to 'NA'
test_df1 = test_df1[test_df1['change_status_date4'] != 'NA']

# %%
# Filter out rows in test_df1 where 'change_status_date5' is not equal to 'NA'
test_df1 = test_df1[test_df1['change_status_date5'] != 'NA']

# %%
# Filter out rows in test_df1 where 'geography_types' is not equal to 'None'
test_df1 = test_df1[test_df1['geography_types'] != 'None']

# %%
# Filter out rows in test_df1 where 'urban_types' is not equal to 'None'
test_df1 = test_df1[test_df1['urban_types'] != 'None']

# %%
# Encoding the categorical column 'geography_types'
le = LabelEncoder()
test_df1['geography_types'] = le.fit_transform(test_df1.geography_types)

# %%
# Encoding the categorical column 'urban_types'
le = LabelEncoder()
test_df1['urban_types'] = le.fit_transform(test_df1.urban_types)

# %%
from shapely.geometry import shape
import pandas as pd

# Calculate the area for each polygon in train_df1
for index, row in test_df1.iterrows():
    geometry = row['geometry']
    superficie = shape(geometry).area
    test_df1.at[index, 'superficie'] = superficie
# Display the DataFrame with the new 'area' column
test_df1
# Out:
#          index change_status_date1 change_status_date2  change_status_date3  \
# 12          12  Prior Construction  Prior Construction   Prior Construction
# 13          13  Prior Construction  Prior Construction   Prior Construction
# 19          19           Greenland        Land Cleared         Land Cleared
# 29          29  Prior Construction  Prior Construction   Prior Construction
# 30          30  Prior Construction  Prior Construction   Prior Construction
# ...        ...                 ...                 ...                  ...
# 121699  121699        Land Cleared        Land Cleared    Construction Done
# 121700  121700           Greenland   Construction Done    Construction Done
# 121701  121701           Greenland           Greenland            Greenland
# 121702  121702        Land Cleared        Land Cleared  Construction Midway
# 121703  121703           Greenland        Land Cleared    Construction Done
#
#         change_status_date4 change_status_date5       date1       date2  \
# 12       Prior Construction        Land Cleared  20-11-2014  29-11-2015
# 13             Land Cleared        Land Cleared  20-11-2014  29-11-2015
# 19        Construction Done   Construction Done  20-11-2014  29-11-2015
# 29       Prior Construction        Land Cleared  20-11-2014  29-11-2015
# 30       Prior Construction        Land Cleared  20-11-2014  29-11-2015
# ...                     ...                 ...         ...         ...
# 121699    Construction Done   Construction Done  30-07-2014  09-02-2015
# 121700    Construction Done   Construction Done  30-07-2014  09-02-2015
# 121701  Construction Midway   Construction Done  30-07-2014  09-02-2015
# 121702    Construction Done   Construction Done  30-07-2014  09-02-2015
# 121703    Construction Done   Construction Done  30-07-2014  09-02-2015
#
#              date3       date4       date5  urban_types  geography_types  \
# 12      16-05-2017  27-10-2018  19-03-2020            5               14
# 13      16-05-2017  27-10-2018  19-03-2020            5               14
# 19      16-05-2017  27-10-2018  19-03-2020            7              142
# 29      16-05-2017  27-10-2018  19-03-2020            7              142
# 30      16-05-2017  27-10-2018  19-03-2020            7              142
# ...            ...         ...         ...          ...              ...
# 121699  02-03-2017  19-08-2018  22-01-2019            7              137
# 121700  02-03-2017  19-08-2018  22-01-2019            7              141
# 121701  02-03-2017  19-08-2018  22-01-2019            7              141
# 121702  02-03-2017  19-08-2018  22-01-2019            7              126
# 121703  02-03-2017  19-08-2018  22-01-2019            7              126
#
#                                                  geometry    superficie
# 12      POLYGON ((103.97511 36.01026, 103.97553 36.010...  1.676424e-07
# 13      POLYGON ((103.97568 36.00978, 103.97568 36.009...  8.368769e-08
# 19      POLYGON ((103.97320 36.00849, 103.97337 36.008...  5.485025e-08
# 29      POLYGON ((103.97346 36.00801, 103.97389 36.007...  5.734509e-08
# 30      POLYGON ((103.97345 36.00784, 103.97379 36.007...  9.594095e-08
# ...                                                   ...           ...
# 121699  POLYGON ((113.21206 29.37929, 113.21213 29.379...  1.468961e-08
# 121700  POLYGON ((113.21203 29.37706, 113.21212 29.376...  2.950373e-08
# 121701  POLYGON ((113.21187 29.37609, 113.21188 29.375...  3.579027e-08
# 121702  POLYGON ((113.21158 29.37573, 113.21162 29.375...  2.281689e-08
# 121703  POLYGON ((113.21204 29.37516, 113.21195 29.375...  2.309111e-08
#
# [102204 rows x 15 columns]

# %%
# Encoding the categorical column 'change_status_date'
le = LabelEncoder()
test_df1['change_status_date4'] = le.fit_transform(test_df1.change_status_date4)

# %%
# Encoding the categorical column 'change_status_date'
le = LabelEncoder()
test_df1['change_status_date1'] = le.fit_transform(test_df1.change_status_date1)

# %%
# Encoding the categorical column 'change_status_date'
le = LabelEncoder()
test_df1['change_status_date2'] = le.fit_transform(test_df1.change_status_date2)

# %%
# Encoding the categorical column 'change_status_date'
le = LabelEncoder()
test_df1['change_status_date3'] = le.fit_transform(test_df1.change_status_date3)

# %%
# Encoding the categorical column 'change_status_date'
le = LabelEncoder()
test_df1['change_status_date5'] = le.fit_transform(test_df1.change_status_date5)

# %%
from datetime import datetime
# Convert strings to datetime objects
test_df1['date1'] = test_df1['date1'].apply(lambda x: datetime.strptime(x, '%d-%m-%Y'))
test_df1['date2'] = test_df1['date2'].apply(lambda x: datetime.strptime(x, '%d-%m-%Y'))
test_df1['date3'] = test_df1['date3'].apply(lambda x: datetime.strptime(x, '%d-%m-%Y'))
test_df1['date4'] = test_df1['date4'].apply(lambda x: datetime.strptime(x, '%d-%m-%Y'))
test_df1['date5'] = test_df1['date5'].apply(lambda x: datetime.strptime(x, '%d-%m-%Y'))


# Calculate the number of days between consecutive dates
test_df1['jours_entre_1_et_2'] = (test_df1['date2'] - test_df1['date1']).dt.days
test_df1['jours_entre_2_et_3'] = (test_df1['date3'] - test_df1['date2']).dt.days
test_df1['jours_entre_3_et_4'] = (test_df1['date4'] - test_df1['date3']).dt.days
test_df1['jours_entre_4_et_5'] = (test_df1['date5'] - test_df1['date4']).dt.days

# %%
# Remove the columns 'date1', 'date2', 'date3', 'date4', 'date5' from test_df1
test_df1 = test_df1.drop(columns=['date1'], axis=1)
test_df1 = test_df1.drop(columns=['date2'], axis=1)
test_df1 = test_df1.drop(columns=['date3'], axis=1)
test_df1 = test_df1.drop(columns=['date4'], axis=1)
test_df1 = test_df1.drop(columns=['date5'], axis=1)

# %%
# Remove the columns 'geometry' from test_df1
test_df1 = test_df1.drop(columns=['geometry'], axis=1)

# %%
test_df1
# Out:
#          index  change_status_date1  change_status_date2  change_status_date3  \
# 12          12                    8                    8                    8
# 13          13                    8                    8                    8
# 19          19                    4                    5                    5
# 29          29                    8                    8                    8
# 30          30                    8                    8                    8
# ...        ...                  ...                  ...                  ...
# 121699  121699                    5                    5                    0
# 121700  121700                    4                    0                    0
# 121701  121701                    4                    4                    4
# 121702  121702                    5                    5                    1
# 121703  121703                    4                    5                    0
#
#         change_status_date4  change_status_date5  urban_types  \
# 12                        8                    5            5
# 13                        5                    5            5
# 19                        0                    0            7
# 29                        8                    5            7
# 30                        8                    5            7
# ...                     ...                  ...          ...
# 121699                    0                    0            7
# 121700                    0                    0            7
# 121701                    1                    0            7
# 121702                    0                    0            7
# 121703                    0                    0            7
#
#         geography_types    superficie  jours_entre_1_et_2  jours_entre_2_et_3  \
# 12                   14  1.676424e-07                 374                 534
# 13                   14  8.368769e-08                 374                 534
# 19                  142  5.485025e-08                 374                 534
# 29                  142  5.734509e-08                 374                 534
# 30                  142  9.594095e-08                 374                 534
# ...                 ...           ...                 ...                 ...
# 121699              137  1.468961e-08                 194                 752
# 121700              141  2.950373e-08                 194                 752
# 121701              141  3.579027e-08                 194                 752
# 121702              126  2.281689e-08                 194                 752
# 121703              126  2.309111e-08                 194                 752
#
#         jours_entre_3_et_4  jours_entre_4_et_5
# 12                     529                 509
# 13                     529                 509
# 19                     529                 509
# 29                     529                 509
# 30                     529                 509
# ...                    ...                 ...
# 121699                 535                 156
# 121700                 535                 156
# 121701                 535                 156
# 121702                 535                 156
# 121703                 535                 156
#
# [102204 rows x 13 columns]

# %% [markdown]
# # prediction and Evaluation

# %%
# Defining the features  (train_x)  and target (train_y)
train_x =  train_df1.drop(columns = ['change_type'])
train_y = train_df1['change_type'].apply(lambda x: change_type_map[x])

# %%
test_x
# Out:
#          index  change_status_date1  change_status_date2  change_status_date3  \
# 12          12                    8                    8                    8
# 13          13                    8                    8                    8
# 19          19                    4                    5                    5
# 29          29                    8                    8                    8
# 30          30                    8                    8                    8
# ...        ...                  ...                  ...                  ...
# 121699  121699                    5                    5                    0
# 121700  121700                    4                    0                    0
# 121701  121701                    4                    4                    4
# 121702  121702                    5                    5                    1
# 121703  121703                    4                    5                    0
#
#         change_status_date4  change_status_date5  urban_types  \
# 12                        8                    5            5
# 13                        5                    5            5
# 19                        0                    0            7
# 29                        8                    5            7
# 30                        8                    5            7
# ...                     ...                  ...          ...
# 121699                    0                    0            7
# 121700                    0                    0            7
# 121701                    1                    0            7
# 121702                    0                    0            7
# 121703                    0                    0            7
#
#         geography_types    superficie  jours_entre_1_et_2  jours_entre_2_et_3  \
# 12                   14  1.676424e-07                 374                 534
# 13                   14  8.368769e-08                 374                 534
# 19                  142  5.485025e-08                 374                 534
# 29                  142  5.734509e-08                 374                 534
# 30                  142  9.594095e-08                 374                 534
# ...                 ...           ...                 ...                 ...
# 121699              137  1.468961e-08                 194                 752
# 121700              141  2.950373e-08                 194                 752
# 121701              141  3.579027e-08                 194                 752
# 121702              126  2.281689e-08                 194                 752
# 121703              126  2.309111e-08                 194                 752
#
#         jours_entre_3_et_4  jours_entre_4_et_5
# 12                     529                 509
# 13                     529                 509
# 19                     529                 509
# 29                     529                 509
# 30                     529                 509
# ...                    ...                 ...
# 121699                 535                 156
# 121700                 535                 156
# 121701                 535                 156
# 121702                 535                 156
# 121703                 535                 156
#
# [102204 rows x 13 columns]

# %%
## Train a simple OnveVsRestClassifier using featurized data
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(train_x, train_y)
pred_y = neigh.predict(test_x)
print (pred_y.shape)
pred_y
# Out:
# (102204,)
# array([3, 3, 3, ..., 2, 2, 2], dtype=int64)

# %% [markdown]
# ## Here are the difficulties I encountered and the solutions I found at each level.

# %% [markdown]
# ### .For the training dataframe (train_df), I noticed that the categories in the "geography_types" variable were not all the same as in the test dataframe (test_df), in fact they were more numerous in the train_df.
#
# ### .The data was voluminous and it took me about 4 minutes to read the JSON files.
#
# ### .The missing values were identified as "None" and "NA" and were deleted as I didn't know the meaning of None. On the other hand, I couldn't impute the NA values because I have no knowledge of the origin of these missing values, so I decided to delete them too in order to have a correct analysis.
#
# ### .As far as adding the calculated geometric data to the dataframe is concerned, I encountered a problem when adding the table converted to dataframe, which led to the appearance of missing values (NAN). So I calculated the area of the polygons in the dataframe using the shapely.geometry library.
#
# ### .I have not been able to evaluate the performance of my model, as I am unable to extract the target labels from the test_df dataset, despite knowing the indexes.
